# %% [markdown]
# # Age from face
# Predict age of a person from an image of their face

# %% [markdown]
# ### Project Repo
# https://github.com/buckcri/age-from-face

# %% [markdown]
# ## Participants:
# Oskar Lachnit, Florian Diedrich, Nils-Christian Buck

# %% [markdown]
# ### Course and Semester
# Deep Learning from Scratch, WiSe2122

# %% [markdown]
# ### License
# Not yet decided
#
# ---

# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
import pathlib
import matplotlib.pyplot as plt

# %%
#NB: Deleted folders for age >93 because there were fee files, but gaps (e.g. no 94 old persons)
#Afterwards class label is equal to index in prediction array
data_dir = "../data/face_age"

# %%
data_dir = pathlib.Path(data_dir)

# %%
batch_size = 32

#Fix seed to achieve determinism
fixed_seed = 42

#10% of data reserved for validation set
validation_split=0.1

#Load both training and validation set. Sets are shuffled by default
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=validation_split,
  subset="training",
  seed=fixed_seed,
  image_size=(100, 100),
  batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=validation_split,
  subset="validation",
  seed=fixed_seed,
  image_size=(100, 100),
  batch_size=batch_size)
# Out:
# Found 9752 files belonging to 93 classes.
# Using 8777 files for training.
# 2021-12-28 13:21:18.563708: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-12-28 13:21:18.563728: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-28 13:21:18.563750: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (39051fad144a): /proc/driver/nvidia/version does not exist
# 2021-12-28 13:21:18.566358: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 9752 files belonging to 93 classes.
# Using 975 files for validation.

# %%
#Show one random image from dataset, including label

example_batch = train_ds.take(1)

#x and y are one batch array of examples and labels
x,y = iter(example_batch).get_next()

example_image = x[0]
example_label = y[0]

plt.imshow(example_image.numpy().astype("uint8"))
plt.title(example_label.numpy())
plt.axis("off")
plt.show()
# Out:
# 2021-12-28 13:21:55.954175: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 100, 100, 3)
# (32,)

# %%
#Count the number of examples for each label
from collections import defaultdict

age_dist = defaultdict(int)

for x_batch,y_batch in train_ds.as_numpy_iterator():
   for i in range(len(y_batch)):
       age_dist[y_batch[i]] += 1

# %%
#Plot above count
plt.bar(list(age_dist.keys()), age_dist.values())
plt.xlabel('Age')
plt.ylabel('#Examples')
plt.show()

# %%
#Number of distinct labels:
num_labels = len(list(age_dist.keys()))

print(num_labels)
# Out:
# 93

# %%
# Define DNN with hidden layers. Rescale pixel values to [0, 1] first.
# There's one output class for each label.
# @see https://www.tensorflow.org/api_docs/python/tf/keras/layers

num_classes = num_labels

#Do not define activation function on output layer as recommended by TF documentation.
#Activation from using from_logits=True in loss function may offer better numerical stability.
model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

#SparseCategoricalCrossentropy is to be used with integer labels (versus one-hot representation)
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy', tf.keras.metrics.TopKCategoricalAccuracy()])

# %%
#Train model

epochs = 50

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

print(model.summary())
# Out:
# Epoch 1/50
# 275/275 [==============================] - 7s 26ms/step - loss: 4.3469 - accuracy: 0.1088 - top_k_categorical_accuracy: 0.7267 - val_loss: 3.9470 - val_accuracy: 0.1087 - val_top_k_categorical_accuracy: 0.8390
# Epoch 2/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.7344 - accuracy: 0.1327 - top_k_categorical_accuracy: 0.4278 - val_loss: 3.6675 - val_accuracy: 0.1374 - val_top_k_categorical_accuracy: 0.3969
# Epoch 3/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.5980 - accuracy: 0.1440 - top_k_categorical_accuracy: 0.3231 - val_loss: 3.6750 - val_accuracy: 0.1272 - val_top_k_categorical_accuracy: 0.2267
# Epoch 4/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.5103 - accuracy: 0.1462 - top_k_categorical_accuracy: 0.2789 - val_loss: 3.7100 - val_accuracy: 0.1405 - val_top_k_categorical_accuracy: 0.4431
# Epoch 5/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.4392 - accuracy: 0.1555 - top_k_categorical_accuracy: 0.2698 - val_loss: 3.6448 - val_accuracy: 0.0923 - val_top_k_categorical_accuracy: 0.1415
# Epoch 6/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.3905 - accuracy: 0.1563 - top_k_categorical_accuracy: 0.2668 - val_loss: 3.4635 - val_accuracy: 0.1569 - val_top_k_categorical_accuracy: 0.2974
# Epoch 7/50
# 275/275 [==============================] - 7s 25ms/step - loss: 3.3531 - accuracy: 0.1628 - top_k_categorical_accuracy: 0.2586 - val_loss: 3.4520 - val_accuracy: 0.1538 - val_top_k_categorical_accuracy: 0.2646
# Epoch 8/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.3147 - accuracy: 0.1668 - top_k_categorical_accuracy: 0.2491 - val_loss: 3.3861 - val_accuracy: 0.1641 - val_top_k_categorical_accuracy: 0.2256
# Epoch 9/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.2783 - accuracy: 0.1707 - top_k_categorical_accuracy: 0.2472 - val_loss: 3.6722 - val_accuracy: 0.1374 - val_top_k_categorical_accuracy: 0.1518
# Epoch 10/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.3097 - accuracy: 0.1679 - top_k_categorical_accuracy: 0.2412 - val_loss: 3.3969 - val_accuracy: 0.1508 - val_top_k_categorical_accuracy: 0.1867
# Epoch 11/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.2399 - accuracy: 0.1716 - top_k_categorical_accuracy: 0.2370 - val_loss: 3.4482 - val_accuracy: 0.1569 - val_top_k_categorical_accuracy: 0.2851
# Epoch 12/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.2043 - accuracy: 0.1760 - top_k_categorical_accuracy: 0.2330 - val_loss: 3.4264 - val_accuracy: 0.1559 - val_top_k_categorical_accuracy: 0.2318
# Epoch 13/50
# 275/275 [==============================] - 7s 25ms/step - loss: 3.1699 - accuracy: 0.1824 - top_k_categorical_accuracy: 0.2341 - val_loss: 3.3052 - val_accuracy: 0.1569 - val_top_k_categorical_accuracy: 0.1805
# Epoch 14/50
# 275/275 [==============================] - 7s 25ms/step - loss: 3.1701 - accuracy: 0.1748 - top_k_categorical_accuracy: 0.2325 - val_loss: 3.3104 - val_accuracy: 0.1579 - val_top_k_categorical_accuracy: 0.1969
# Epoch 15/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.1419 - accuracy: 0.1808 - top_k_categorical_accuracy: 0.2289 - val_loss: 3.3573 - val_accuracy: 0.1385 - val_top_k_categorical_accuracy: 0.1600
# Epoch 16/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.1131 - accuracy: 0.1850 - top_k_categorical_accuracy: 0.2299 - val_loss: 3.3140 - val_accuracy: 0.1528 - val_top_k_categorical_accuracy: 0.1969
# Epoch 17/50
# 275/275 [==============================] - 7s 25ms/step - loss: 3.1084 - accuracy: 0.1850 - top_k_categorical_accuracy: 0.2315 - val_loss: 3.3873 - val_accuracy: 0.1395 - val_top_k_categorical_accuracy: 0.1826
# Epoch 18/50
# 275/275 [==============================] - 7s 25ms/step - loss: 3.0994 - accuracy: 0.1840 - top_k_categorical_accuracy: 0.2317 - val_loss: 3.5911 - val_accuracy: 0.1415 - val_top_k_categorical_accuracy: 0.1815
# Epoch 19/50
# 275/275 [==============================] - 7s 25ms/step - loss: 3.0759 - accuracy: 0.1918 - top_k_categorical_accuracy: 0.2295 - val_loss: 3.3922 - val_accuracy: 0.1456 - val_top_k_categorical_accuracy: 0.2041
# Epoch 20/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.0475 - accuracy: 0.1945 - top_k_categorical_accuracy: 0.2257 - val_loss: 3.3627 - val_accuracy: 0.1456 - val_top_k_categorical_accuracy: 0.1846
# Epoch 21/50
# 275/275 [==============================] - 7s 26ms/step - loss: 3.0164 - accuracy: 0.1948 - top_k_categorical_accuracy: 0.2209 - val_loss: 3.3575 - val_accuracy: 0.1477 - val_top_k_categorical_accuracy: 0.1744
# Epoch 22/50
# 275/275 [==============================] - 8s 29ms/step - loss: 2.9882 - accuracy: 0.1993 - top_k_categorical_accuracy: 0.2224 - val_loss: 3.4216 - val_accuracy: 0.1405 - val_top_k_categorical_accuracy: 0.1651
# Epoch 23/50
# 275/275 [==============================] - 8s 28ms/step - loss: 2.9859 - accuracy: 0.1987 - top_k_categorical_accuracy: 0.2293 - val_loss: 3.4727 - val_accuracy: 0.1518 - val_top_k_categorical_accuracy: 0.2441
# Epoch 24/50
# 275/275 [==============================] - 8s 28ms/step - loss: 2.9234 - accuracy: 0.2103 - top_k_categorical_accuracy: 0.2249 - val_loss: 3.4025 - val_accuracy: 0.1385 - val_top_k_categorical_accuracy: 0.1774
# Epoch 25/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.9778 - accuracy: 0.2026 - top_k_categorical_accuracy: 0.2264 - val_loss: 3.4261 - val_accuracy: 0.1662 - val_top_k_categorical_accuracy: 0.2031
# Epoch 26/50
# 275/275 [==============================] - 7s 27ms/step - loss: 2.9345 - accuracy: 0.2109 - top_k_categorical_accuracy: 0.2243 - val_loss: 3.4599 - val_accuracy: 0.1682 - val_top_k_categorical_accuracy: 0.2297
# Epoch 27/50
# 275/275 [==============================] - 8s 27ms/step - loss: 2.9236 - accuracy: 0.2074 - top_k_categorical_accuracy: 0.2247 - val_loss: 3.4118 - val_accuracy: 0.1456 - val_top_k_categorical_accuracy: 0.1805
# Epoch 28/50
# 275/275 [==============================] - 7s 27ms/step - loss: 2.8803 - accuracy: 0.2165 - top_k_categorical_accuracy: 0.2262 - val_loss: 3.4186 - val_accuracy: 0.1549 - val_top_k_categorical_accuracy: 0.1867
# Epoch 29/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.8649 - accuracy: 0.2141 - top_k_categorical_accuracy: 0.2190 - val_loss: 3.3978 - val_accuracy: 0.1528 - val_top_k_categorical_accuracy: 0.1805
# Epoch 30/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.8217 - accuracy: 0.2247 - top_k_categorical_accuracy: 0.2243 - val_loss: 3.5515 - val_accuracy: 0.1518 - val_top_k_categorical_accuracy: 0.1713
# Epoch 31/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.8915 - accuracy: 0.2201 - top_k_categorical_accuracy: 0.2250 - val_loss: 3.5280 - val_accuracy: 0.1426 - val_top_k_categorical_accuracy: 0.1795
# Epoch 32/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.8114 - accuracy: 0.2209 - top_k_categorical_accuracy: 0.2231 - val_loss: 3.6579 - val_accuracy: 0.1436 - val_top_k_categorical_accuracy: 0.1549
# Epoch 33/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.8396 - accuracy: 0.2271 - top_k_categorical_accuracy: 0.2191 - val_loss: 3.5186 - val_accuracy: 0.1385 - val_top_k_categorical_accuracy: 0.1836
# Epoch 34/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.7962 - accuracy: 0.2282 - top_k_categorical_accuracy: 0.2246 - val_loss: 3.5866 - val_accuracy: 0.1467 - val_top_k_categorical_accuracy: 0.1887
# Epoch 35/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.7838 - accuracy: 0.2385 - top_k_categorical_accuracy: 0.2225 - val_loss: 3.5750 - val_accuracy: 0.1579 - val_top_k_categorical_accuracy: 0.2062
# Epoch 36/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.7278 - accuracy: 0.2468 - top_k_categorical_accuracy: 0.2202 - val_loss: 3.5962 - val_accuracy: 0.1672 - val_top_k_categorical_accuracy: 0.2338
# Epoch 37/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.7260 - accuracy: 0.2445 - top_k_categorical_accuracy: 0.2222 - val_loss: 3.6699 - val_accuracy: 0.1538 - val_top_k_categorical_accuracy: 0.2318
# Epoch 38/50
# 275/275 [==============================] - 8s 29ms/step - loss: 2.6737 - accuracy: 0.2569 - top_k_categorical_accuracy: 0.2202 - val_loss: 3.6535 - val_accuracy: 0.1528 - val_top_k_categorical_accuracy: 0.2010
# Epoch 39/50
# 275/275 [==============================] - 7s 25ms/step - loss: 2.7020 - accuracy: 0.2521 - top_k_categorical_accuracy: 0.2222 - val_loss: 3.6489 - val_accuracy: 0.1426 - val_top_k_categorical_accuracy: 0.1897
# Epoch 40/50
# 275/275 [==============================] - 7s 25ms/step - loss: 2.6628 - accuracy: 0.2566 - top_k_categorical_accuracy: 0.2217 - val_loss: 3.7127 - val_accuracy: 0.1610 - val_top_k_categorical_accuracy: 0.2277
# Epoch 41/50
# 275/275 [==============================] - 7s 25ms/step - loss: 2.6454 - accuracy: 0.2545 - top_k_categorical_accuracy: 0.2224 - val_loss: 3.7334 - val_accuracy: 0.1467 - val_top_k_categorical_accuracy: 0.1815
# Epoch 42/50
# 275/275 [==============================] - 7s 25ms/step - loss: 2.6114 - accuracy: 0.2654 - top_k_categorical_accuracy: 0.2206 - val_loss: 3.9115 - val_accuracy: 0.1426 - val_top_k_categorical_accuracy: 0.2431
# Epoch 43/50
# 275/275 [==============================] - 7s 25ms/step - loss: 2.6213 - accuracy: 0.2651 - top_k_categorical_accuracy: 0.2196 - val_loss: 3.7913 - val_accuracy: 0.1303 - val_top_k_categorical_accuracy: 0.1805
# Epoch 44/50
# 275/275 [==============================] - 7s 25ms/step - loss: 2.6090 - accuracy: 0.2682 - top_k_categorical_accuracy: 0.2209 - val_loss: 3.7533 - val_accuracy: 0.1487 - val_top_k_categorical_accuracy: 0.1754
# Epoch 45/50
# 275/275 [==============================] - 7s 25ms/step - loss: 2.5812 - accuracy: 0.2734 - top_k_categorical_accuracy: 0.2215 - val_loss: 3.9258 - val_accuracy: 0.1549 - val_top_k_categorical_accuracy: 0.1928
# Epoch 46/50
# 275/275 [==============================] - 7s 25ms/step - loss: 2.5665 - accuracy: 0.2748 - top_k_categorical_accuracy: 0.2202 - val_loss: 3.8236 - val_accuracy: 0.1446 - val_top_k_categorical_accuracy: 0.1846
# Epoch 47/50
# 275/275 [==============================] - 7s 25ms/step - loss: 2.5319 - accuracy: 0.2844 - top_k_categorical_accuracy: 0.2205 - val_loss: 4.0877 - val_accuracy: 0.1569 - val_top_k_categorical_accuracy: 0.2154
# Epoch 48/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.5039 - accuracy: 0.2879 - top_k_categorical_accuracy: 0.2188 - val_loss: 3.8752 - val_accuracy: 0.1344 - val_top_k_categorical_accuracy: 0.1651
# Epoch 49/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.5234 - accuracy: 0.2865 - top_k_categorical_accuracy: 0.2175 - val_loss: 4.1172 - val_accuracy: 0.1313 - val_top_k_categorical_accuracy: 0.1826
# Epoch 50/50
# 275/275 [==============================] - 7s 26ms/step - loss: 2.4629 - accuracy: 0.2925 - top_k_categorical_accuracy: 0.2196 - val_loss: 3.9663 - val_accuracy: 0.1456 - val_top_k_categorical_accuracy: 0.1959
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 100, 100, 3)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 30000)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               7680256
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 93)                11997
# =================================================================
# Total params: 7,741,661
# Trainable params: 7,741,661
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

num_epochs = range(len(accuracy))

plt.plot(num_epochs, accuracy, label='Accuracy Train')
plt.plot(num_epochs, val_accuracy, label='Accuracy Validation')
plt.legend(loc=0)
plt.xticks(num_epochs)
plt.title('Train and Validation accuracy')
plt.show()


loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(num_epochs, loss, label='Loss Train')
plt.plot(num_epochs, val_loss, label='Loss Validation')
plt.legend(loc=0)
plt.xticks(num_epochs)
plt.title('Train and Validation loss')
plt.show()

# %%
def mean_avg_top_k(predictions, k=5):
    """Returns the average of the top k (default: k=5) best predictions' index (index equals age in our case)    
    """
    pred_index_list=sorted(((value, key) for (key,value) in enumerate(predictions[0])), reverse=True)
    sorted_index_pred_list=list([(key,value) for value,key in pred_index_list])

    avg = 0
    for i in range(k):
        key, value = sorted_index_pred_list[i]
        avg+=key
    avg/=k
    
    return avg

# %%
#Show one random image from dataset, including label

example_batch = val_ds.take(1)

#x and y are one batch array of examples and labels
x,y = iter(example_batch).get_next()

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(x[i].numpy().astype("uint8"))
    plt.title(y[i].numpy())
    plt.axis("off")
    plt.suptitle("Real")
    
plt.show()    
    
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(x[i].numpy().astype("uint8"))
    predictions = model.predict(np.expand_dims(x[i], axis=0))
    best_prediction = np.argmax(predictions)
    #No need to map prediction index to label, because they are identical in our case
    plt.title(best_prediction)
    plt.axis("off")
    plt.suptitle("Predicted (argmax)")
    
plt.show()

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(x[i].numpy().astype("uint8"))
    predictions = model.predict(np.expand_dims(x[i], axis=0))
    avg = mean_avg_top_k(predictions)
    plt.title(avg)
    plt.axis("off")
    plt.suptitle("Predicted (top k)")
    
plt.show()

# %%
print("Predictions for last example:")
print(predictions)
# Out:
# Predictions for last example:
# [[  3.7938416   4.382383    3.4970827   3.2587764   1.3197793   1.3218459
#     2.2434912   2.10456     1.9518582   1.5388279  -0.9772546  -0.9227094
#    -1.1355958  -3.692246   -8.29675    -4.715722   -7.1592975  -1.2665894
#   -16.200932   -6.8156343  -7.7817197  -4.976547   -5.782771   -6.2360654
#   -11.590503   -3.9037504  -3.4915912  -8.931638   -9.20989    -9.288709
#    -4.9418526  -6.335752  -12.528068   -9.568756   -9.0858755  -9.12083
#   -11.727708  -10.021021  -10.093992  -13.419143  -10.00381    -9.462563
#   -14.9817095 -11.440851  -10.766357  -19.81522    -5.2501335 -11.968283
#   -11.51291    -9.492559   -9.114737   -5.384288  -13.269772  -12.497569
#   -15.588277  -11.014358   -9.135525  -11.60579   -11.595853   -4.418553
#    -9.578358  -16.017456  -19.178288  -10.207537   -8.204832   -3.5968628
#   -15.475222   -8.062815  -18.798536   -4.4068584 -10.089995  -14.36674
#    -4.9192863 -24.425398   -8.51977   -15.292404  -25.299982  -20.289701
#   -22.309074   -5.505223  -24.64583   -23.705065  -17.428143  -22.265633
#    -4.381483   -5.8706713 -38.864136  -14.901518  -16.444307   -4.8176355
#   -71.32706   -20.060246  -25.014715 ]]

# %% [markdown]
# Papers:
#
# * S. N. Kohail:
# Using Artificial Neural Network for Human Age Estimation Based on Facial Images
# 2012 International Conference on Innovations in Information Technology (IIT)
# https://www.inf.uni-hamburg.de/en/inst/ab/lt/people/alumni/sarah-kohail/kohail-age-estimation.pdf
#
# * Z. Qawaqneh, A. Abu Mallouh & B. D. Barkana:
# Deep Convolutional Neural Network for Age Estimation based on VGG-Face Model
# https://arxiv.org/ftp/arxiv/papers/1709/1709.01664.pdf
#
# * N. Hewahi, A. Olwan, N. Tubeel, S. El-Asar, Z. Abu-Sultan:
# Age Estimation based on Neural Networks using Face Features
# Journal of Emerging Trends in Computing and Information Sciences 1:2, October 2010
# https://www.researchgate.net/publication/47277288_Age_Estimation_based_on_Neural_Networks_using_Face_Features
#
# * R. Rahadian & S. Suyanto:
# Deep Residual Neural Network for Age Classification with Face Image
# 2019 International Seminar on Research of Information Technology and Intelligent Systems (ISRITI)
# https://ieeexplore.ieee.org/document/9034664
#
# * M. M. Islam & J.-H. Baek:
# Deep Learning Based Real Age and Gender Estimation from Unconstrained Face Image towards Smart Store Customer Relationship Management
# Applied Sciences 2021, 11
# https://www.mdpi.com/2076-3417/11/10/4549/pdf
#
# * A. Othmania, A. R. Taleb, H. Abdelkawy & A. Hadid:
# Age estimation from faces using deep learning: A comparative analysis
# Computer Vision and Image Understanding 196, July 2020
# https://www.sciencedirect.com/science/article/abs/pii/S1077314220300424
#
# Additional links:
#
# * https://towardsdatascience.com/age-detection-using-facial-images-traditional-machine-learning-vs-deep-learning-2437b2feeab2

# %%
# Define DNN with hidden layers. Rescale pixel values to [0, 1] first.
# There's one output class for each label.
# @see https://www.tensorflow.org/api_docs/python/tf/keras/layers

num_classes = num_labels

dropout_rate = 0.25

#Do not define activation function on output layer as recommended by TF documentation.
#Activation from using from_logits=True in loss function may offer better numerical stability.
model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(dropout_rate),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(dropout_rate),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(num_classes)
])

#SparseCategoricalCrossentropy is to be used with integer labels (versus one-hot representation)
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy', tf.keras.metrics.TopKCategoricalAccuracy()])

# %%
#Train model

epochs = 60

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

print(model.summary())
# Out:
# Epoch 1/80
# 275/275 [==============================] - 14s 50ms/step - loss: 4.1279 - accuracy: 0.1163 - top_k_categorical_accuracy: 0.3627 - val_loss: 4.0277 - val_accuracy: 0.0810 - val_top_k_categorical_accuracy: 0.3497
# Epoch 2/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.6413 - accuracy: 0.1433 - top_k_categorical_accuracy: 0.3074 - val_loss: 3.7315 - val_accuracy: 0.1344 - val_top_k_categorical_accuracy: 0.2287
# Epoch 3/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.5324 - accuracy: 0.1478 - top_k_categorical_accuracy: 0.2991 - val_loss: 4.0946 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 0.3169
# Epoch 4/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.4546 - accuracy: 0.1504 - top_k_categorical_accuracy: 0.2863 - val_loss: 4.1723 - val_accuracy: 0.0544 - val_top_k_categorical_accuracy: 0.0646
# Epoch 5/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.4086 - accuracy: 0.1591 - top_k_categorical_accuracy: 0.2864 - val_loss: 4.6887 - val_accuracy: 0.0369 - val_top_k_categorical_accuracy: 0.0236
# Epoch 6/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.3744 - accuracy: 0.1618 - top_k_categorical_accuracy: 0.2738 - val_loss: 4.1461 - val_accuracy: 0.1303 - val_top_k_categorical_accuracy: 0.3231
# Epoch 7/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.3519 - accuracy: 0.1663 - top_k_categorical_accuracy: 0.2780 - val_loss: 3.6040 - val_accuracy: 0.1364 - val_top_k_categorical_accuracy: 0.2031
# Epoch 8/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2942 - accuracy: 0.1700 - top_k_categorical_accuracy: 0.2687 - val_loss: 3.5974 - val_accuracy: 0.1385 - val_top_k_categorical_accuracy: 0.2072
# Epoch 9/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2753 - accuracy: 0.1714 - top_k_categorical_accuracy: 0.2756 - val_loss: 4.5364 - val_accuracy: 0.0369 - val_top_k_categorical_accuracy: 0.0246
# Epoch 10/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2464 - accuracy: 0.1718 - top_k_categorical_accuracy: 0.2773 - val_loss: 3.7659 - val_accuracy: 0.1313 - val_top_k_categorical_accuracy: 0.1969
# Epoch 11/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2098 - accuracy: 0.1779 - top_k_categorical_accuracy: 0.2677 - val_loss: 4.9107 - val_accuracy: 0.1128 - val_top_k_categorical_accuracy: 0.2174
# Epoch 12/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2405 - accuracy: 0.1765 - top_k_categorical_accuracy: 0.2741 - val_loss: 3.5566 - val_accuracy: 0.1385 - val_top_k_categorical_accuracy: 0.2205
# Epoch 13/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.2355 - accuracy: 0.1735 - top_k_categorical_accuracy: 0.2691 - val_loss: 4.9180 - val_accuracy: 0.1015 - val_top_k_categorical_accuracy: 0.1323
# Epoch 14/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2108 - accuracy: 0.1804 - top_k_categorical_accuracy: 0.2691 - val_loss: 3.7365 - val_accuracy: 0.1385 - val_top_k_categorical_accuracy: 0.1949
# Epoch 15/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1871 - accuracy: 0.1784 - top_k_categorical_accuracy: 0.2680 - val_loss: 3.5507 - val_accuracy: 0.1272 - val_top_k_categorical_accuracy: 0.2308
# Epoch 16/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1643 - accuracy: 0.1812 - top_k_categorical_accuracy: 0.2652 - val_loss: 3.4471 - val_accuracy: 0.1415 - val_top_k_categorical_accuracy: 0.2041
# Epoch 17/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1413 - accuracy: 0.1815 - top_k_categorical_accuracy: 0.2690 - val_loss: 3.6692 - val_accuracy: 0.1231 - val_top_k_categorical_accuracy: 0.1179
# Epoch 18/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2011 - accuracy: 0.1808 - top_k_categorical_accuracy: 0.2668 - val_loss: 4.0047 - val_accuracy: 0.1385 - val_top_k_categorical_accuracy: 0.4646
# Epoch 19/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.2839 - accuracy: 0.1714 - top_k_categorical_accuracy: 0.2771 - val_loss: 4.1809 - val_accuracy: 0.0892 - val_top_k_categorical_accuracy: 0.1272
# Epoch 20/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2406 - accuracy: 0.1714 - top_k_categorical_accuracy: 0.2697 - val_loss: 4.5693 - val_accuracy: 0.0482 - val_top_k_categorical_accuracy: 0.0585
# Epoch 21/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2198 - accuracy: 0.1785 - top_k_categorical_accuracy: 0.2745 - val_loss: 3.6860 - val_accuracy: 0.1282 - val_top_k_categorical_accuracy: 0.2133
# Epoch 22/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.3093 - accuracy: 0.1662 - top_k_categorical_accuracy: 0.2920 - val_loss: 3.6789 - val_accuracy: 0.1323 - val_top_k_categorical_accuracy: 0.1538
# Epoch 23/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.2419 - accuracy: 0.1724 - top_k_categorical_accuracy: 0.2845 - val_loss: 3.7056 - val_accuracy: 0.1323 - val_top_k_categorical_accuracy: 0.3118
# Epoch 24/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2224 - accuracy: 0.1751 - top_k_categorical_accuracy: 0.2816 - val_loss: 3.5926 - val_accuracy: 0.1303 - val_top_k_categorical_accuracy: 0.1826
# Epoch 25/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1843 - accuracy: 0.1751 - top_k_categorical_accuracy: 0.2796 - val_loss: 3.5127 - val_accuracy: 0.1395 - val_top_k_categorical_accuracy: 0.1590
# Epoch 26/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1784 - accuracy: 0.1805 - top_k_categorical_accuracy: 0.2690 - val_loss: 3.5931 - val_accuracy: 0.1446 - val_top_k_categorical_accuracy: 0.2123
# Epoch 27/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1874 - accuracy: 0.1806 - top_k_categorical_accuracy: 0.2754 - val_loss: 3.4314 - val_accuracy: 0.1272 - val_top_k_categorical_accuracy: 0.1887
# Epoch 28/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1763 - accuracy: 0.1766 - top_k_categorical_accuracy: 0.2726 - val_loss: 3.3358 - val_accuracy: 0.1621 - val_top_k_categorical_accuracy: 0.2031
# Epoch 29/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1674 - accuracy: 0.1761 - top_k_categorical_accuracy: 0.2693 - val_loss: 3.5005 - val_accuracy: 0.1467 - val_top_k_categorical_accuracy: 0.2267
# Epoch 30/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.1397 - accuracy: 0.1820 - top_k_categorical_accuracy: 0.2725 - val_loss: 3.4864 - val_accuracy: 0.1149 - val_top_k_categorical_accuracy: 0.2133
# Epoch 31/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.1382 - accuracy: 0.1797 - top_k_categorical_accuracy: 0.2741 - val_loss: 4.0563 - val_accuracy: 0.0933 - val_top_k_categorical_accuracy: 0.1231
# Epoch 32/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.3413 - accuracy: 0.1666 - top_k_categorical_accuracy: 0.3012 - val_loss: 3.4694 - val_accuracy: 0.1569 - val_top_k_categorical_accuracy: 0.2277
# Epoch 33/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.2754 - accuracy: 0.1682 - top_k_categorical_accuracy: 0.2884 - val_loss: 4.0910 - val_accuracy: 0.1118 - val_top_k_categorical_accuracy: 0.1303
# Epoch 34/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.2499 - accuracy: 0.1693 - top_k_categorical_accuracy: 0.2808 - val_loss: 4.5559 - val_accuracy: 0.0995 - val_top_k_categorical_accuracy: 0.1210
# Epoch 35/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.2873 - accuracy: 0.1657 - top_k_categorical_accuracy: 0.2926 - val_loss: 3.4105 - val_accuracy: 0.1713 - val_top_k_categorical_accuracy: 0.2677
# Epoch 36/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.2601 - accuracy: 0.1711 - top_k_categorical_accuracy: 0.2872 - val_loss: 3.7883 - val_accuracy: 0.1241 - val_top_k_categorical_accuracy: 0.2215
# Epoch 37/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.3070 - accuracy: 0.1610 - top_k_categorical_accuracy: 0.3050 - val_loss: 3.8091 - val_accuracy: 0.1446 - val_top_k_categorical_accuracy: 0.2892
# Epoch 38/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.3137 - accuracy: 0.1577 - top_k_categorical_accuracy: 0.3259 - val_loss: 3.4253 - val_accuracy: 0.1631 - val_top_k_categorical_accuracy: 0.2974
# Epoch 39/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.3117 - accuracy: 0.1594 - top_k_categorical_accuracy: 0.3172 - val_loss: 3.7171 - val_accuracy: 0.1364 - val_top_k_categorical_accuracy: 0.1323
# Epoch 40/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2807 - accuracy: 0.1645 - top_k_categorical_accuracy: 0.3083 - val_loss: 3.4401 - val_accuracy: 0.1610 - val_top_k_categorical_accuracy: 0.2185
# Epoch 41/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2694 - accuracy: 0.1620 - top_k_categorical_accuracy: 0.3117 - val_loss: 3.4989 - val_accuracy: 0.1621 - val_top_k_categorical_accuracy: 0.3303
# Epoch 42/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2710 - accuracy: 0.1641 - top_k_categorical_accuracy: 0.3102 - val_loss: 3.4875 - val_accuracy: 0.1518 - val_top_k_categorical_accuracy: 0.1867
# Epoch 43/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2461 - accuracy: 0.1633 - top_k_categorical_accuracy: 0.3091 - val_loss: 3.4890 - val_accuracy: 0.1436 - val_top_k_categorical_accuracy: 0.1826
# Epoch 44/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.2396 - accuracy: 0.1629 - top_k_categorical_accuracy: 0.2963 - val_loss: 3.3457 - val_accuracy: 0.1549 - val_top_k_categorical_accuracy: 0.2123
# Epoch 45/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.2250 - accuracy: 0.1683 - top_k_categorical_accuracy: 0.2954 - val_loss: 3.9657 - val_accuracy: 0.1087 - val_top_k_categorical_accuracy: 0.1323
# Epoch 46/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.2327 - accuracy: 0.1661 - top_k_categorical_accuracy: 0.2986 - val_loss: 3.5187 - val_accuracy: 0.1497 - val_top_k_categorical_accuracy: 0.1662
# Epoch 47/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2156 - accuracy: 0.1674 - top_k_categorical_accuracy: 0.2870 - val_loss: 3.6193 - val_accuracy: 0.1518 - val_top_k_categorical_accuracy: 0.2359
# Epoch 48/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2068 - accuracy: 0.1676 - top_k_categorical_accuracy: 0.2919 - val_loss: 3.3738 - val_accuracy: 0.1754 - val_top_k_categorical_accuracy: 0.2482
# Epoch 49/80
# 275/275 [==============================] - 13s 49ms/step - loss: 3.1889 - accuracy: 0.1716 - top_k_categorical_accuracy: 0.3003 - val_loss: 3.4699 - val_accuracy: 0.1672 - val_top_k_categorical_accuracy: 0.3128
# Epoch 50/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2048 - accuracy: 0.1750 - top_k_categorical_accuracy: 0.2945 - val_loss: 3.6286 - val_accuracy: 0.1538 - val_top_k_categorical_accuracy: 0.2492
# Epoch 51/80
# 275/275 [==============================] - 13s 49ms/step - loss: 3.1896 - accuracy: 0.1699 - top_k_categorical_accuracy: 0.3007 - val_loss: 3.6261 - val_accuracy: 0.1323 - val_top_k_categorical_accuracy: 0.1549
# Epoch 52/80
# 275/275 [==============================] - 13s 49ms/step - loss: 3.1717 - accuracy: 0.1734 - top_k_categorical_accuracy: 0.2898 - val_loss: 3.9189 - val_accuracy: 0.1046 - val_top_k_categorical_accuracy: 0.0851
# Epoch 53/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1686 - accuracy: 0.1722 - top_k_categorical_accuracy: 0.2856 - val_loss: 4.6003 - val_accuracy: 0.1262 - val_top_k_categorical_accuracy: 0.4205
# Epoch 54/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1895 - accuracy: 0.1702 - top_k_categorical_accuracy: 0.2856 - val_loss: 3.6417 - val_accuracy: 0.1641 - val_top_k_categorical_accuracy: 0.4338
# Epoch 55/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1655 - accuracy: 0.1696 - top_k_categorical_accuracy: 0.2868 - val_loss: 3.4059 - val_accuracy: 0.1713 - val_top_k_categorical_accuracy: 0.2605
# Epoch 56/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1491 - accuracy: 0.1733 - top_k_categorical_accuracy: 0.2869 - val_loss: 3.6508 - val_accuracy: 0.1374 - val_top_k_categorical_accuracy: 0.1292
# Epoch 57/80
# 275/275 [==============================] - 14s 51ms/step - loss: 3.1560 - accuracy: 0.1722 - top_k_categorical_accuracy: 0.2849 - val_loss: 3.5348 - val_accuracy: 0.1692 - val_top_k_categorical_accuracy: 0.2379
# Epoch 58/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.1491 - accuracy: 0.1726 - top_k_categorical_accuracy: 0.2843 - val_loss: 3.5774 - val_accuracy: 0.1600 - val_top_k_categorical_accuracy: 0.2113
# Epoch 59/80
# 275/275 [==============================] - 13s 49ms/step - loss: 3.1343 - accuracy: 0.1731 - top_k_categorical_accuracy: 0.2770 - val_loss: 3.6376 - val_accuracy: 0.1426 - val_top_k_categorical_accuracy: 0.1467
# Epoch 60/80
# 275/275 [==============================] - 13s 49ms/step - loss: 3.1322 - accuracy: 0.1761 - top_k_categorical_accuracy: 0.2856 - val_loss: 3.4904 - val_accuracy: 0.1744 - val_top_k_categorical_accuracy: 0.2359
# Epoch 61/80
# 275/275 [==============================] - 13s 49ms/step - loss: 3.1463 - accuracy: 0.1742 - top_k_categorical_accuracy: 0.2892 - val_loss: 3.6275 - val_accuracy: 0.1610 - val_top_k_categorical_accuracy: 0.1610
# Epoch 62/80
# 275/275 [==============================] - 13s 49ms/step - loss: 3.1402 - accuracy: 0.1732 - top_k_categorical_accuracy: 0.2824 - val_loss: 3.6594 - val_accuracy: 0.1477 - val_top_k_categorical_accuracy: 0.3672
# Epoch 63/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.1443 - accuracy: 0.1740 - top_k_categorical_accuracy: 0.2869 - val_loss: 3.6137 - val_accuracy: 0.1395 - val_top_k_categorical_accuracy: 0.1600
# Epoch 64/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.1359 - accuracy: 0.1733 - top_k_categorical_accuracy: 0.2838 - val_loss: 3.8505 - val_accuracy: 0.1344 - val_top_k_categorical_accuracy: 0.1467
# Epoch 65/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.1073 - accuracy: 0.1739 - top_k_categorical_accuracy: 0.2787 - val_loss: 3.4958 - val_accuracy: 0.1703 - val_top_k_categorical_accuracy: 0.3374
# Epoch 66/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.1183 - accuracy: 0.1731 - top_k_categorical_accuracy: 0.2764 - val_loss: 3.5736 - val_accuracy: 0.1508 - val_top_k_categorical_accuracy: 0.1764
# Epoch 67/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1142 - accuracy: 0.1724 - top_k_categorical_accuracy: 0.2829 - val_loss: 4.0522 - val_accuracy: 0.1241 - val_top_k_categorical_accuracy: 0.1251
# Epoch 68/80
# 275/275 [==============================] - 13s 49ms/step - loss: 3.1036 - accuracy: 0.1755 - top_k_categorical_accuracy: 0.2765 - val_loss: 3.5238 - val_accuracy: 0.1467 - val_top_k_categorical_accuracy: 0.1415
# Epoch 69/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.1090 - accuracy: 0.1777 - top_k_categorical_accuracy: 0.2783 - val_loss: 3.5532 - val_accuracy: 0.1508 - val_top_k_categorical_accuracy: 0.1703
# Epoch 70/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2245 - accuracy: 0.1620 - top_k_categorical_accuracy: 0.3025 - val_loss: 4.6161 - val_accuracy: 0.1262 - val_top_k_categorical_accuracy: 0.4831
# Epoch 71/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.2946 - accuracy: 0.1557 - top_k_categorical_accuracy: 0.3388 - val_loss: 3.8333 - val_accuracy: 0.1313 - val_top_k_categorical_accuracy: 0.1538
# Epoch 72/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.5158 - accuracy: 0.1404 - top_k_categorical_accuracy: 0.4257 - val_loss: 3.7922 - val_accuracy: 0.1303 - val_top_k_categorical_accuracy: 0.2267
# Epoch 73/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.5199 - accuracy: 0.1404 - top_k_categorical_accuracy: 0.4601 - val_loss: 3.6586 - val_accuracy: 0.1426 - val_top_k_categorical_accuracy: 0.3374
# Epoch 74/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.4956 - accuracy: 0.1442 - top_k_categorical_accuracy: 0.4457 - val_loss: 3.8425 - val_accuracy: 0.1467 - val_top_k_categorical_accuracy: 0.2759
# Epoch 75/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.4896 - accuracy: 0.1453 - top_k_categorical_accuracy: 0.4528 - val_loss: 4.4406 - val_accuracy: 0.1251 - val_top_k_categorical_accuracy: 0.7559
# Epoch 76/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.8181 - accuracy: 0.1284 - top_k_categorical_accuracy: 0.5693 - val_loss: 4.1669 - val_accuracy: 0.1200 - val_top_k_categorical_accuracy: 0.5405
# Epoch 77/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.7809 - accuracy: 0.1309 - top_k_categorical_accuracy: 0.5555 - val_loss: 4.2246 - val_accuracy: 0.1251 - val_top_k_categorical_accuracy: 0.1938
# Epoch 78/80
# 275/275 [==============================] - 14s 49ms/step - loss: 3.7704 - accuracy: 0.1307 - top_k_categorical_accuracy: 0.5476 - val_loss: 4.1612 - val_accuracy: 0.1138 - val_top_k_categorical_accuracy: 0.7703
# Epoch 79/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.7691 - accuracy: 0.1311 - top_k_categorical_accuracy: 0.5438 - val_loss: 4.0718 - val_accuracy: 0.1221 - val_top_k_categorical_accuracy: 0.7159
# Epoch 80/80
# 275/275 [==============================] - 14s 50ms/step - loss: 3.7580 - accuracy: 0.1309 - top_k_categorical_accuracy: 0.5330 - val_loss: 3.8731 - val_accuracy: 0.1241 - val_top_k_categorical_accuracy: 0.3856
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_2 (Rescaling)      (None, 100, 100, 3)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 30000)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               15360512
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_11 (Dense)             (None, 93)                23901
# =================================================================
# Total params: 15,783,517
# Trainable params: 15,780,957
# Non-trainable params: 2,560
# _________________________________________________________________
# None

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

num_epochs = range(len(accuracy))

plt.plot(num_epochs, accuracy, label='Accuracy Train')
plt.plot(num_epochs, val_accuracy, label='Accuracy Validation')
plt.legend(loc=0)
plt.xticks(num_epochs)
plt.title('Train and Validation accuracy')
plt.show()


loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(num_epochs, loss, label='Loss Train')
plt.plot(num_epochs, val_loss, label='Loss Validation')
plt.legend(loc=0)
plt.xticks(num_epochs)
plt.title('Train and Validation loss')
plt.show()

# %%
#Show one random image from dataset, including label

example_batch = val_ds.take(1)

#x and y are one batch array of examples and labels
x,y = iter(example_batch).get_next()

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(x[i].numpy().astype("uint8"))
    plt.title(y[i].numpy())
    plt.axis("off")
    plt.suptitle("Real")
    
plt.show()    
    
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(x[i].numpy().astype("uint8"))
    predictions = model.predict(np.expand_dims(x[i], axis=0))
    best_prediction = np.argmax(predictions)
    #No need to map prediction index to label, because they are identical in our case
    plt.title(best_prediction)
    plt.axis("off")
    plt.suptitle("Predicted (argmax)")
    
plt.show()

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(x[i].numpy().astype("uint8"))
    predictions = model.predict(np.expand_dims(x[i], axis=0))
    avg = mean_avg_top_k(predictions)
    plt.title(avg)
    plt.axis("off")
    plt.suptitle("Predicted (top k)")
    
plt.show()

# %%
#Number of years to group together
age_grouping = 7

def label_group_mapping(x, y):
    return x, y//age_grouping

train_ds_grouped = train_ds.map(label_group_mapping)
val_ds_grouped = val_ds.map(label_group_mapping)

# %%
# Define DNN with hidden layers. Rescale pixel values to [0, 1] first.

num_classes = num_labels//age_grouping
if ((num_labels % age_grouping) != 0):
    num_classes+=1

print(f"Grouped {num_labels} labels to {num_classes} classes with stride {age_grouping}.")

dropout_rate = 0.2

#Do not define activation function on output layer as recommended by TF documentation.
#Activation from using from_logits=True in loss function may offer better numerical stability.
model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(768, activation='relu'),
  tf.keras.layers.Dropout(dropout_rate),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dropout(dropout_rate),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(dropout_rate),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(num_classes)
])

#SparseCategoricalCrossentropy is to be used with integer labels (versus one-hot representation)
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy', tf.keras.metrics.TopKCategoricalAccuracy()])
# Out:
# Grouped 93 labels to 14 classes with stride 7.

# %%
#Train model

epochs = 20

history = model.fit(
  train_ds_grouped,
  validation_data=val_ds_grouped,
  epochs=epochs
)

print(model.summary())
# Out:
# Epoch 1/20
# 275/275 [==============================] - 20s 70ms/step - loss: 2.2415 - accuracy: 0.3127 - top_k_categorical_accuracy: 0.4569 - val_loss: 2.0074 - val_accuracy: 0.3231 - val_top_k_categorical_accuracy: 0.2544
# Epoch 2/20
# 275/275 [==============================] - 19s 68ms/step - loss: 1.8751 - accuracy: 0.3779 - top_k_categorical_accuracy: 0.4606 - val_loss: 2.1114 - val_accuracy: 0.2769 - val_top_k_categorical_accuracy: 0.2010
# Epoch 3/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.7623 - accuracy: 0.3897 - top_k_categorical_accuracy: 0.4490 - val_loss: 2.3556 - val_accuracy: 0.2626 - val_top_k_categorical_accuracy: 0.2626
# Epoch 4/20
# 275/275 [==============================] - 20s 71ms/step - loss: 1.7237 - accuracy: 0.3999 - top_k_categorical_accuracy: 0.4551 - val_loss: 1.8735 - val_accuracy: 0.3477 - val_top_k_categorical_accuracy: 0.4923
# Epoch 5/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.6869 - accuracy: 0.4085 - top_k_categorical_accuracy: 0.4570 - val_loss: 1.9229 - val_accuracy: 0.3559 - val_top_k_categorical_accuracy: 0.2872
# Epoch 6/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.6389 - accuracy: 0.4187 - top_k_categorical_accuracy: 0.4467 - val_loss: 1.9766 - val_accuracy: 0.3682 - val_top_k_categorical_accuracy: 0.5651
# Epoch 7/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.6173 - accuracy: 0.4266 - top_k_categorical_accuracy: 0.4521 - val_loss: 2.0125 - val_accuracy: 0.3241 - val_top_k_categorical_accuracy: 0.2687
# Epoch 8/20
# 275/275 [==============================] - 19s 68ms/step - loss: 1.6038 - accuracy: 0.4295 - top_k_categorical_accuracy: 0.4569 - val_loss: 2.1311 - val_accuracy: 0.3067 - val_top_k_categorical_accuracy: 0.2492
# Epoch 9/20
# 275/275 [==============================] - 19s 68ms/step - loss: 1.6147 - accuracy: 0.4269 - top_k_categorical_accuracy: 0.4498 - val_loss: 4.1372 - val_accuracy: 0.0585 - val_top_k_categorical_accuracy: 0.0041
# Epoch 10/20
# 275/275 [==============================] - 19s 67ms/step - loss: 1.6046 - accuracy: 0.4217 - top_k_categorical_accuracy: 0.4511 - val_loss: 1.8071 - val_accuracy: 0.3805 - val_top_k_categorical_accuracy: 0.3508
# Epoch 11/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.5800 - accuracy: 0.4358 - top_k_categorical_accuracy: 0.4454 - val_loss: 1.7448 - val_accuracy: 0.3846 - val_top_k_categorical_accuracy: 0.4369
# Epoch 12/20
# 275/275 [==============================] - 19s 68ms/step - loss: 1.5662 - accuracy: 0.4435 - top_k_categorical_accuracy: 0.4405 - val_loss: 1.7628 - val_accuracy: 0.3651 - val_top_k_categorical_accuracy: 0.5897
# Epoch 13/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.6275 - accuracy: 0.4236 - top_k_categorical_accuracy: 0.4564 - val_loss: 2.5303 - val_accuracy: 0.2595 - val_top_k_categorical_accuracy: 0.9733
# Epoch 14/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.6940 - accuracy: 0.4048 - top_k_categorical_accuracy: 0.4651 - val_loss: 2.1986 - val_accuracy: 0.2872 - val_top_k_categorical_accuracy: 0.7251
# Epoch 15/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.6764 - accuracy: 0.4055 - top_k_categorical_accuracy: 0.4581 - val_loss: 1.8964 - val_accuracy: 0.3354 - val_top_k_categorical_accuracy: 0.4205
# Epoch 16/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.6292 - accuracy: 0.4224 - top_k_categorical_accuracy: 0.4484 - val_loss: 2.3800 - val_accuracy: 0.2431 - val_top_k_categorical_accuracy: 0.1764
# Epoch 17/20
# 275/275 [==============================] - 19s 69ms/step - loss: 1.7017 - accuracy: 0.4015 - top_k_categorical_accuracy: 0.4780 - val_loss: 1.8927 - val_accuracy: 0.3538 - val_top_k_categorical_accuracy: 0.3569
# Epoch 18/20
# 275/275 [==============================] - 19s 70ms/step - loss: 1.7453 - accuracy: 0.3852 - top_k_categorical_accuracy: 0.4990 - val_loss: 1.7322 - val_accuracy: 0.3641 - val_top_k_categorical_accuracy: 0.3405
# Epoch 19/20
# 275/275 [==============================] - 20s 71ms/step - loss: 1.7077 - accuracy: 0.3866 - top_k_categorical_accuracy: 0.4715 - val_loss: 1.9991 - val_accuracy: 0.3262 - val_top_k_categorical_accuracy: 0.7200
# Epoch 20/20
# 275/275 [==============================] - 20s 72ms/step - loss: 1.6795 - accuracy: 0.3990 - top_k_categorical_accuracy: 0.4699 - val_loss: 1.8285 - val_accuracy: 0.3610 - val_top_k_categorical_accuracy: 0.3621
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_20 (Rescaling)     (None, 100, 100, 3)       0
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 30000)             0
# _________________________________________________________________
# dense_76 (Dense)             (None, 768)               23040768
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 768)               3072
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 768)               0
# _________________________________________________________________
# dense_77 (Dense)             (None, 256)               196864
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_78 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_79 (Dense)             (None, 14)                1806
# =================================================================
# Total params: 23,276,942
# Trainable params: 23,274,638
# Non-trainable params: 2,304
# _________________________________________________________________
# None

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

num_epochs = range(len(accuracy))

plt.plot(num_epochs, accuracy, label='Accuracy Train')
plt.plot(num_epochs, val_accuracy, label='Accuracy Validation')
plt.legend(loc=0)
plt.xticks(num_epochs)
plt.title('Train and Validation accuracy')
plt.show()


loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(num_epochs, loss, label='Loss Train')
plt.plot(num_epochs, val_loss, label='Loss Validation')
plt.legend(loc=0)
plt.xticks(num_epochs)
plt.title('Train and Validation loss')
plt.show()

# %%
def to_grouped_age_range(age_class):
    lower_bound = age_class*age_grouping
    upper_bound = ((age_class+1)*age_grouping)-1
    return "{} ({}-{})".format(age_class, lower_bound, upper_bound)

# %%
#Show one random image from dataset, including label

example_batch = val_ds_grouped.take(1)

#x and y are one batch array of examples and labels
x,y = iter(example_batch).get_next()

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(x[i].numpy().astype("uint8"))
    plt.title(to_grouped_age_range(y[i].numpy()))
    #plt.title(y[i].numpy())
    plt.axis("off")
    plt.suptitle("Real")
    
plt.show()    
    
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(x[i].numpy().astype("uint8"))
    predictions = model.predict(np.expand_dims(x[i], axis=0))
    best_prediction = np.argmax(predictions)
    plt.title(to_grouped_age_range(best_prediction))
    #lt.title(best_prediction)
    plt.axis("off")
    plt.suptitle("Predicted (argmax)")
    
plt.show()

# %%
print("Predictions for last example:")
print(predictions)
print(best_prediction)
# Out:
# Predictions for last example:
# [[ 1.5144192   0.42341888  0.51152766  0.61192554  0.20793064  0.1614122
#   -0.24045572  0.20826843 -0.03497439 -0.3681337  -0.72186506 -1.112631
#   -0.7568105  -3.3968487 ]]
# 0
